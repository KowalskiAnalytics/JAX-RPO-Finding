# %%
run1 = """0:  |F(x)| = 3.5238; step 0.454
1:  |F(x)| = 3.1223; step 0.0549774
2:  |F(x)| = 3.26895; step 1
3:  |F(x)| = 3.3605; step 0.491453
4:  |F(x)| = 3.29896; step 0.0488432
5:  |F(x)| = 2.66257; step 0.413859
6:  |F(x)| = 2.55189; step 1
7:  |F(x)| = 2.65474; step 0.311274
8:  |F(x)| = 2.44723; step 0.129937
9:  |F(x)| = 2.30723; step 0.165782
10:  |F(x)| = 3.23334; step 1
11:  |F(x)| = 3.15109; step 1
12:  |F(x)| = 2.89915; step 0.288595
13:  |F(x)| = 2.87342; step 0.0260654
14:  |F(x)| = 2.8552; step 0.0241104
15:  |F(x)| = 2.78639; step 0.103795
16:  |F(x)| = 2.14936; step 0.293837
17:  |F(x)| = 1.98459; step 0.111031
18:  |F(x)| = 1.98261; step 0.111316
19:  |F(x)| = 1.84349; step 0.311645
20:  |F(x)| = 3.10211; step 1
21:  |F(x)| = 3.09952; step 1
22:  |F(x)| = 2.85667; step 0.117873
23:  |F(x)| = 2.59965; step 0.0452593
24:  |F(x)| = 2.9537; step 1
25:  |F(x)| = 2.93323; step 0.0567383
26:  |F(x)| = 2.44423; step 1
27:  |F(x)| = 2.30981; step 0.0654812
28:  |F(x)| = 2.26461; step 0.01032
29:  |F(x)| = 2.14092; step 0.0128724
30:  |F(x)| = 2.12673; step 0.0069747
31:  |F(x)| = 2.25165; step 0.0770591
32:  |F(x)| = 2.23073; step 0.0181835
33:  |F(x)| = 2.23443; step 0.0158513
34:  |F(x)| = 2.25238; step 0.0228394
35:  |F(x)| = 2.27067; step 0.0347796
36:  |F(x)| = 2.27195; step 0.00662519
37:  |F(x)| = 2.44052; step 1
38:  |F(x)| = 2.4183; step 0.038275
39:  |F(x)| = 2.41023; step 0.0092147
40:  |F(x)| = 2.41846; step 0.0429288
41:  |F(x)| = 2.41689; step 0.0293783
42:  |F(x)| = 2.41595; step 0.00251558
43:  |F(x)| = 2.41449; step 0.00432989
44:  |F(x)| = 2.3989; step 0.0146502
45:  |F(x)| = 2.39013; step 0.0127617
46:  |F(x)| = 2.37024; step 0.0359602
47:  |F(x)| = 2.36388; step 0.00846984
48:  |F(x)| = 2.32553; step 0.0394424
49:  |F(x)| = 2.08505; step 0.170475
50:  |F(x)| = 2.08076; step 0.0556002
51:  |F(x)| = 2.65334; step 1
52:  |F(x)| = 2.51084; step 0.106644
53:  |F(x)| = 2.28286; step 0.115059
54:  |F(x)| = 2.06359; step 0.104022
55:  |F(x)| = 2.00381; step 0.150704
56:  |F(x)| = 1.94471; step 0.0789003
57:  |F(x)| = 1.89863; step 0.108341
58:  |F(x)| = 1.79997; step 0.0765394
59:  |F(x)| = 1.71738; step 0.0664082
60:  |F(x)| = 1.63289; step 0.0717709
61:  |F(x)| = 1.54292; step 0.0887778
62:  |F(x)| = 1.40714; step 0.147751
63:  |F(x)| = 1.22056; step 0.237883
64:  |F(x)| = 1.18878; step 0.0393759
65:  |F(x)| = 0.843986; step 1
66:  |F(x)| = 0.837808; step 0.0328527
67:  |F(x)| = 0.815137; step 0.123361
68:  |F(x)| = 0.807332; step 0.0584147
69:  |F(x)| = 0.802143; step 0.0462212
70:  |F(x)| = 0.799292; step 0.017172
71:  |F(x)| = 0.795295; step 0.0231205
72:  |F(x)| = 0.790564; step 0.0276503
73:  |F(x)| = 0.784339; step 0.0487266
74:  |F(x)| = 0.775416; step 0.0714859
75:  |F(x)| = 0.771007; step 0.0808915
76:  |F(x)| = 0.765487; step 0.069836
77:  |F(x)| = 0.765119; step 0.0128416
78:  |F(x)| = 0.749913; step 0.147004
79:  |F(x)| = 0.753591; step 0.0666187"""

run2 = """0:  |F(x)| = 0.390695; step 0.00313356
1:  |F(x)| = 0.389561; step 0.00298296
2:  |F(x)| = 0.38848; step 0.00291004
3:  |F(x)| = 0.387433; step 0.00289421
4:  |F(x)| = 0.386404; step 0.00293275
5:  |F(x)| = 0.385376; step 0.00303823
6:  |F(x)| = 0.384322; step 0.00324726
7:  |F(x)| = 0.383195; step 0.00365473
8:  |F(x)| = 0.381883; step 0.00453071
9:  |F(x)| = 0.380146; step 0.00654956
10:  |F(x)| = 0.378611; step 0.00656527
11:  |F(x)| = 0.377747; step 0.00416699
12:  |F(x)| = 0.376746; step 0.00527319
13:  |F(x)| = 0.371484; step 0.0344881
14:  |F(x)| = 0.370434; step 0.142975
15:  |F(x)| = 0.38254; step 0.491499
16:  |F(x)| = 0.379352; step 0.500014
17:  |F(x)| = 0.37935; step 1
18:  |F(x)| = 0.379352; step 1
19:  |F(x)| = 0.37935; step 1
20:  |F(x)| = 0.379352; step 1
21:  |F(x)| = 0.37935; step 1
22:  |F(x)| = 0.379352; step 1
23:  |F(x)| = 0.37935; step 1
24:  |F(x)| = 0.379352; step 1
25:  |F(x)| = 0.367201; step 1
26:  |F(x)| = 0.387298; step 0.358542
27:  |F(x)| = 0.377608; step 0.194132
28:  |F(x)| = 0.380809; step 0.0964153
29:  |F(x)| = 0.378076; step 0.101026
30:  |F(x)| = 0.369078; step 1
31:  |F(x)| = 0.3726; step 1
32:  |F(x)| = 0.381297; step 1
33:  |F(x)| = 0.379414; step 0.00741802
34:  |F(x)| = 0.378264; step 0.00519063
35:  |F(x)| = 0.377516; step 0.00372186
36:  |F(x)| = 0.375881; step 0.00894322
37:  |F(x)| = 0.368487; step 0.0588968
38:  |F(x)| = 0.375467; step 0.152158
39:  |F(x)| = 0.38008; step 0.0773983
40:  |F(x)| = 0.401554; step 1
41:  |F(x)| = 0.379275; step 1
42:  |F(x)| = 0.475422; step 1
43:  |F(x)| = 0.373082; step 1
44:  |F(x)| = 0.368615; step 1
45:  |F(x)| = 0.360979; step 0.264485
46:  |F(x)| = 0.384365; step 1
47:  |F(x)| = 0.351943; step 1
48:  |F(x)| = 0.339573; step 0.371698
49:  |F(x)| = 0.346181; step 0.117833
50:  |F(x)| = 0.354314; step 0.461029
51:  |F(x)| = 0.347407; step 0.054413
52:  |F(x)| = 0.297498; step 1
53:  |F(x)| = 0.136417; step 1
54:  |F(x)| = 0.023024; step 1
55:  |F(x)| = 0.0230239; step 4.59377e-06
56:  |F(x)| = 0.0230238; step 4.60287e-06
57:  |F(x)| = 0.0230237; step 4.60428e-06
58:  |F(x)| = 0.0230236; step 4.61076e-06
59:  |F(x)| = 0.0230234; step 4.64091e-06
60:  |F(x)| = 0.0230233; step 4.66205e-06
61:  |F(x)| = 0.0230232; step 4.67334e-06
62:  |F(x)| = 0.0230231; step 4.72323e-06
63:  |F(x)| = 0.023023; step 4.73094e-06
64:  |F(x)| = 0.0230229; step 4.75661e-06
65:  |F(x)| = 0.0230228; step 4.75955e-06
66:  |F(x)| = 0.0230227; step 4.77152e-06
67:  |F(x)| = 0.0230226; step 4.7818e-06
68:  |F(x)| = 0.0230225; step 4.78874e-06
69:  |F(x)| = 0.0230223; step 4.82385e-06
70:  |F(x)| = 0.0230222; step 4.85798e-06
71:  |F(x)| = 0.0230221; step 4.87116e-06
72:  |F(x)| = 0.023022; step 4.93319e-06
73:  |F(x)| = 0.0230219; step 4.95721e-06
74:  |F(x)| = 0.0230218; step 4.98925e-06
75:  |F(x)| = 0.0230216; step 4.99552e-06
76:  |F(x)| = 0.0230215; step 5.01152e-06
77:  |F(x)| = 0.0230214; step 5.02535e-06
78:  |F(x)| = 0.0230213; step 5.03542e-06
79:  |F(x)| = 0.0230212; step 5.08349e-06"""

# %%
import matplotlib.pyplot as plt
import numpy as np

def convergence(run):
    run = run.split('\n')
    Fmag, step = [], []

    for line in run:
        line = line.split()
        Fmag.append(float(line[3][:-1]))
        step.append(float(line[5]))
    
    return np.float64(Fmag), np.float64(step)


fig=plt.figure()
ax1=fig.add_subplot(211)
ax2=fig.add_subplot(212)
runs = [run1, run2]
for n, run in enumerate(runs):
    Fmag, step = convergence(run)
    ax1.plot(Fmag, label=f'run{n} residual')
    ax2.plot(step, label=f'run{n} stepsize')

ax1.legend()
ax2.legend()
